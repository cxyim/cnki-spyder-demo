# %%
import requests
from bs4 import BeautifulSoup
from pprint import pprint as fprint
import csv

# %%
def get_author_url_set(author_name):
    cookies = {"Ecp_ClientId":"8181230144300598948","cnkiUserKey":"f7539957-65af-525e-faa1-06827035cf6a","UM_distinctid":"168901af2db2e5-0f9d022615f7b4-b781636-1fa400-168901af2dda1b","Ecp_IpLoginFail":"190131144.202.106.13","SID":"110105","CNZZDATA1257838113":"2120179519-1548925778-http%253A%252F%252Fsearch.cnki.net%252F%7C1548925778","KEYWORD":"%E7%89%9B%E4%B8%BD%E6%85%A7"}
    headers = {"Host":"yuanjian.cnki.net","Proxy-Connection":"keep-alive","Content-Length":"63","Cache-Control":"max-age=0","Origin":"http://yuanjian.cnki.net","Upgrade-Insecure-Requests":"1","DNT":"1","Content-Type":"application/x-www-form-urlencoded","User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36","Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8","Referer":"http://yuanjian.cnki.net/","Accept-Encoding":"gzip, deflate","Accept-Language":"zh-CN,zh;q=0.9,en;q=0.8"}
    base_url = "http://yuanjian.cnki.net/Search/Result"
    data = {"searchType":"MulityTermsSearch","Author":author_name}
    
    r = requests.post(base_url,cookies = cookies,headers = headers,data = data)
    bs = BeautifulSoup(r.text)
    res = bs.find_all("span",{"style":"color:red"})
    url_set = set()
    for item in res:
        url_set.add(item.parent["href"])
    return url_set

# %%
def get_author_url_set_test():
    author_name = "陈云鹏"
    fprint(get_author_url_set(author_name))
# get_author_url_set_test()

# %%
def get_doc_url_set(author_url_set):
    url_set = set()
    for author_url in author_url_set:  
        r = requests.get(author_url)
        bs = BeautifulSoup(r.text)
        res = bs.find_all("p",{"class":"tit clearfix"})
        for item in res:
            url_set.add(item.a["href"])
    return url_set

# %%
# fprint(get_doc_url_set(get_author_url_set("陈云鹏")))

# %%
def get_doc_bibilo(doc_url_set):
    res_file = open("res.csv","w",encoding="utf-8",newline="")
    csv_writer = csv.writer(res_file,delimiter="\t")
    
    for doc_url in doc_url_set:
        r = requests.get(doc_url)
        bs = BeautifulSoup(r.text)
        
        #journal
        try:
            journal = bs.find("b").text.strip()
        except:
            journal = " "

        #title
        title = bs.find("h1").text.strip()

        #author
        res = bs.find("div",{"style":"text-align:center; width:740px; height:30px;"})
        author_list = list()
        for item in res.find_all("a"):
            author_list.append(item.string.strip())

        #abstract
#         try:
#             abstract = bs.find("div",{"style":"text-align:left;word-break:break-all"}).font.next_sibling.string.strip()
#         except:
#             abstract = " "

        #address
        try:
            address = bs.find("div",{"style":"text-align:left;"}).a.string.strip()
        except:
            address = " "
            
        #keywords
        try:
            keyword_list = bs.find("meta",{"name":"keywords"})["content"].split()
        except:
            keyword_list = []

        #year
        try:
            year = bs.find("font",{"color":"#0080ff"}).string.strip()[:4]
        except:
            year = " "
        
        tmp = (title,";".join(author_list),journal,address,year,";".join(keyword_list))
        csv_writer.writerow(tmp)
    
    res_file.close()

# %%
get_doc_bibilo(get_doc_url_set(get_author_url_set("陈云鹏")))
# Out:
# ('国内外标准文献开放获取资源的分析', '李景;汪滨;魏利伟;潘薇;陈云鹏;李菁;旻苏;赵萍;王霞;李波;赵奇', '《标准科学》', '中国标准化研究院;', '2011', '开放获取;标准信息资源;标准制定组织', '文章对60个国家和地区(含国际组织)的1241个机构6大类组织机构类型的961个网站进行了全面、系统地调研、梳理、翻译、编辑、整理和统计,下载了可开放获取的标准信息资源10869份电子文件,文件格式包含pdf文件、html格式网页、txt文本及zip格式压缩文件;信息资源类型涉及报告、认证、标准规范类(含手册、指南,草案和征求意见稿)、法律法规、目录、专著及期刊,共计7大类资源;并介绍了标准制定组织的OA状态和趋势。')
# ('覆膜铁的产品特性及其国内外发展状况', '陈云鹏;黄久贵;李建中;田彦文;刘常升', '《轧钢》', '宝山钢铁股份有限公司宝钢分公司冷轧薄板厂;东北大学材料与冶金学院;', '2010', '覆膜铁;特性;发展状况;应用', '介绍了覆膜铁的生产工艺、产品特性及发展历程,并分析了国内外覆膜铁产品的应用现状及前景。')
# ('企业自我声明标准合规性评价方法初探', '计雄飞;王霞;陈云鹏;张明', '《标准科学》', '中国标准化研究院;', '2017', '企业标准;合规性;评价方法', '本文主要针对企业自我声明的产品和服务标准中存在的问题,研究企业自我声明的标准合规性评价内容、方法和流程,通过具体案例详细分析了企业自我声明的标准中存在的问题及产生的原因,并对企业自我声明标准合规性评价工作提出了建议。')
# ('基于五要素模型的标准影响力评价方法研究', '陈云鹏;周国民;汪滨;谢晨', '《图书情报工作》', '中国农业科学院研究生院;中国标准化研究院;', '2016', '五要素模型;文献计量标准;采用;影响力;评价', '[目的 /意义]提出一种基于五要素模型的标准采用影响力评价方法,实现对标准影响力的定量测度。[方法 /过程]五要素模型标准采用影响力评价方法从采用强度、采用效度、采用广度、采用粘度和转化速度5个维度来评价标准采用的影响力,使用此方法开展2006-2015年ISO标准对我国推荐性国家标准的采用影响力评价分析。[结果 /结论]五要素模型作为定量测度标准文献采用影响力的方法,具有评价指标全面、可量化的优点,能够较全面、客观地反映标准采用影响力的相关要素。')
# ('湖北省高校高水平运动队教学与训练现状及对策', '代永胜;陈云鹏;陈亮', '《体育成人教育学刊》', '湖北工业大学体育部', '2007', '高水平运动队;教学与训练;湖北省高校', '采用文献资料法及专家访谈法,对湖北省具备特招资格的14所高校高水平运动队教学与训练现状进行调查与分析,指出了当前教学与训练过程中存在的一些问题,并针对这些问题提出了合理化的对策与建议。')
# ('面向服务的标准信息专题知识组织', '计雄飞;胡雄伟;张宝林;李国鹏;刘智洋;王玉琢;陈云鹏;王震', '《标准科学》', '中国标准化研究院;', '2010', '标准文献;标准服务;知识组织;专题服务', '文章通过分析国内外标准信息专题服务现状,指出当前国内标准文献服务机构在服务过程中存在的问题。通过市场调查,推测出今后标准文献服务的发展趋势是通过对标准信息进行专题知识组织来开展多类型的专题服务,通过自身开展的试点研究总结出一套标准信息知识组织流程。')
# ('标准信息公益服务模式研究——以国家标准文献共享服务平台为例', '汪滨;陈云鹏;张明;王霞;高燕', '《标准科学》', '中国标准化研究院;', '2015', '国家标准文献共享平台;服务模式;公益服务', '国家标准文献共享平台构建的一体化的数据检索服务、系统化的数据推送服务、集成化的数据专题服务以及知识化的数据挖掘服务,初步构建了新型的集"文献-信息-情报-知识"于一体的标准公益服务模式,这是我国开展标准信息公益服务的有益探索。')
# ('高校体育立法可行性研究', '陈云鹏;曾伟', '《湖北体育科技》', '湖北工业大学体育部;', '2014', '高校教育;体育;体育立法', '作为高等教育的重要组成部分,高校体育在高等教育中扮演着重要的角色。我国高校体育在市场经济体制下运行面临着大量错综复杂的教育行为和法律关系。为了更好地适应高等教育发展的方向和市场的调节,妥善调整这些法律关系,保证高校体育事业在社会发展中具有的重要战略地位,就必须为高校体育工作制定相应的高校体育法规,高校体育立法的首要作用就在于此。从宏观层面上看,高校体育立法为高校体育事业的战略地位提供法律保障,也为高校体育事业能快速发展注入了新的动力。')
# ('技术竞争情报在企业标准化领域的应用', '陈云鹏', '《标准科学》', '中国标准化研究院;', '2012', '技术竞争情报;标准化;标准化战略;竞争情报服务', '本文首先阐述了技术竞争情报的概念、方法和作用,继而讨论了企业技术标准化战略的概念、作用和目标并论述了企业技术标准化战略管理流程中的竞争情报需求。文章最后论述了标准化领域开展技术竞争情报服务的方法和类型。')
# ('做官先做人  万事民为先', '陈云鹏', '《山西政报》', ' ', '2004', '重要思想;郑培民;三个代表;群众利益;领导干部;新时期;共产党人;人民群众;生产生活;权为民所用', '正 郑培民同志是新时期领导干部的优秀代表。他以自己的模范行为和崇高品德,赢得了广大群众的衷心赞誉;以自己毕生的精力践行了他的行为准则,真正做到了"权为民所用,情为民所系,利为民所谋",忠实实践了"三个代表"重要思想,集中体现了当代共产党人的精神风貌。郑培民同志的先进事迹折射出很多可贵的精神,"勿以民利之小而不为"就是这些可贵精神之一。胡锦涛同志在"‘三个代表’重要思想理论研讨会"上强调指出:"群众利益无小事。凡是涉及群众的切身利益和实际困难的事情,再小也要竭尽全力去办。要时刻把群众的安危冷暖挂在心上,对群众生产生活面临的这样那样的困难,特别是对')
# ('监管NGO的理论分析——以社会管理创新为背景', '陈云鹏', '《中共山西省委党校学报》', '山西经济管理干部学院;', '2011', 'NGO;监管;合理性;必要性', 'NGO(非政府组织)是社会发展到一定阶段的必然产物。在社会管理创新时期,要保障NGO的健康发展,必须对其加强监管。基于支持NGO发展的委托——代理理论、志愿失灵理论、社会法团主义理论、社会性规制理论和公共产品理论,加强对其监管的合理性、合法性和必要性研究,对NGO承载更多的社会公共责任具有重要的现实意义。')
# ('吹树脂颗粒法除漆对复合材料性能的影响', '陈云鹏;孙涛;陈雁骉', '《航空维修与工程》', '国营芜湖机械厂', '2018', 'PMB;复合材料;除漆', '复合材料的性能特点使其表面漆层除漆困难。本文介绍了一种吹树脂颗粒法(PMB)除漆技术,论述了其工作原理和工艺流程。选用T700和EW240复合材料作为样件,通过检测除漆前后的外观形貌、分层脱粘、层间剪切强度、弯曲强度等性能,分析该除漆技术对复合材料性能的影响。结果表明,采用PMB技术进行复合材料除漆,未对复合材料性能产生不利影响,除漆效果达到预定要求。')
# ('微电流电絮凝技术在高浊度水处理中的应用研究', '陈云鹏', '《长江科学院》', ' ', '2018', '高浊度水;微电流电絮凝;砂石骨料废水;洗车废水;高藻水', '传统絮凝沉淀难以有效去除高浊度(60NTU)废水中的有机与无机细颗粒悬浮物,微电流电絮凝通过微弱电流(电流密度一般为几到几十毫安每平方厘米)电解阳极产生具有活性的氢氧化物,进而絮凝沉淀各类悬浮物,该技术具有无药剂添加及二次污染、能耗较低和易于操控等优点,是一种环境友好的电化学水处理技术。论文选取了砂石骨料废水、洗车废水、高藻水等具有不同类型悬浮物的高浊度水进行了微电流电絮凝处理试验,分析了电极材料、电流密度、电解时间、电极间距等对浊度及其它特征污染物去除的影响,通过能耗能效分析,优化了相应的技术参数,探讨了相关机理,主要研究结论如下:(1)查明了微电流电絮凝处理砂石骨料废水的性能及技术参数,结果表明,相对于铁电极,铝电极更适合做阳极来处理砂石骨料废水,且不会增加水体色度。砂石骨料废水经过2h自然沉降后再进行电絮凝,对悬浮物的处理效果更好。电絮凝处理砂石骨料废水,建议初始悬浮物浓度不宜超过50000mg/L,电流强度不超过0.08A,电解时间不超过4min。电絮凝改变了砂石骨料废水中悬浮物颗粒粒径组成,电絮凝对于粒径在1~2μm间的颗粒有较好的沉降效果。(2)确定了微电流电絮凝处理洗车废水的性能及技术参数,结果表明,微电流电絮凝可以较好去除洗车废水的浊度、COD与LAS,并对pH影响较小,在电极间距1.5cm,电流强度0.16A和电解时间低于15min时,能效最优。此时洗车废水浊度降幅可达85%,COD与LAS的去除率分别达到60%与65%。(3)优化了微电流电絮凝处理高藻水的性能及技术参数,结果表明,微电流电絮凝可以有效削减高藻水的藻密度、浊度、总氮和总磷含量,当极板间距控制在1.5cm,电流强度不高于0.16A,电解时间不超过15min,电解质浓度不超过0.05g/L时,高藻水电絮凝处理能效最优,此时浊度、总氮与总磷的去除率分别可达到68%、90%和88%。(4)微电流电絮凝处理含不同类型悬浮物高浊度水的机理主要为电气浮、电凝聚、电解氧化还原,三种作用往往同时发生于整个电絮凝过程,三者的协同作用促进了不同浊度物质的高效去除。')
# ('浅谈新形势下村级组织建设', '陈云鹏', '《中共山西省委党校学报》', '山西经济管理干部学院!山西太原030012', '2000', '村级组织;村级组织建设;农村', '文章分析了当前农村发展过程中村级组织的三种表现形式 ,农村村级组织形式中存在的问题对农村各项方针、政策及农村社会经济持续发展的影响 ,并有针对性地提出了解决这些问题的办法。')
# ('当代中国政府机构改革中的范式选择', '任晓林;陈云鹏', '《中共山西省委党校学报》', '陕西延安大学!陕西', '2001', '范式;模式;政府机构', '从行政范式解析入手，提出范式代替模式的新观点。对政治领袖范式、官僚制范式、企业型政府范式进行了结构上的重新认识。趋利避害，重建新范式是当代中国政府机构改革的必然选择。')
# ('关于我国标准起草人署名的历史探轶及现状研究', '陈云鹏', '《中国标准导报》', '中国标准化研究院;', '2012', '标准起草人;署名;历史;现状', '本文对我国标准起草人署名的历史由来及现状进行了梳理分析,指出标准起草人署名同标准化工作绩效评价的紧密关联。同时对标准起草人署名的贡献和问题进行了梳理,并对标准起草人署名的相关问题提出了建议。')
# ('短小芽孢杆菌表达系统的优化研究', '陈云鹏', '《复旦大学》', ' ', '2004', '', "真菌病害是造成农作物产量损失的重要原因之一,利用天然的或经遗传改良\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n的微生物进行植物真菌病害的防治是当前国际上较为活跃的研究领域之一。本实\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n验室已从水稻叶片上分离出一株附生菌 DX01,经试验证明该菌具有天然拮抗某\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n些真菌的特性,若能进一步将其定向改造成具有更强抗真菌能力的工程菌,作为\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n生物农药的有效组分,从而可以减少因使用化学农药而造成的环境污染,无疑具\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n有重要的理论和现实意义。绿色荧光蛋白(GFP)基因作为标记基因,被广泛应用\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n于环境微生物学方面,由于其表达稳定,容易观测,因此,也可以作为启动子活\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n性的报告基因。为了进一步优化短小芽孢杆菌表达系统,以 GFP 作为报告基因,\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n对克隆自 DX01 菌株的启动子进行了一系列的研究。\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n 采用 PCR 技术,亚克隆来自短小芽孢杆菌 (Bacillus brevis) DX01 菌株总基\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n因组中的启动子活性片段 F1,分别构建了大肠杆菌组成型表达载体\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\npUC118-F1gfp 和一个大肠杆菌-短小芽孢杆菌穿梭表达载体 pHY300-F1gfp,以缺\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n失启动子的绿色荧光蛋白 (GFP) 基因为报告基因,检测了该片段在大肠杆菌\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nDH5α 和短小芽孢杆菌 DX01 菌株中的启动活性,在荧光显微镜下,均观察到了\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n明亮的绿色荧光,证实活性片段 F1 具有组成型启动子的功能,gfp 基因在 2 种宿\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n主细胞中实现了组成型表达。该表达结果为 Western 印迹所证实。对 2 种宿主表\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n达细胞中 GFP 蛋白的表达量作了 FACS 分析,结果表明 gfp 基因在 DX01 细胞中\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n的表达强度约为 DH5α 中的 2 倍。\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n 运用来自噬菌体 Mu 的转座酶 MuA,对启动子 F1 进行了随机插入突变,从\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n中筛选出 13 个 F1 的突变体。对突变体的氯霉素抗性检测表明,与 F1 对照相比,\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n7 个含相应突变体的菌株其氯霉素抗性水平有显著提高,其中突变体 Fm3 和\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nFm10 抗性提高了 3.6 倍,可抗高达 900μg/mL 氯霉素,揭示这些启动子突变体有\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n着更高的启动活性;4 个突变体氯霉素抗性水平下降;2 个突变体抗性水平基本\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n不变。CAT-ELISA 检测的结果,也进一步证实了氯霉素抗性水平的变化与 CAT\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n酶活力的变化有着密切的关系。在启动子 F1 的 DNA 序列上,存在着不同插入\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n效应敏感位点,在这些位点附近的插入突变,可使启动活性急剧变化,并且相邻\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n的插入位点,其突变效应可能完全不同。FACS 分析表明,在大肠杆菌中表现为\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n启动活性增强的 F1 突变体,转入短小芽孢杆菌 DX01 后其活性仍表现为增强。\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n 采用 RT-PCR 方法,克隆了萝卜抗真菌蛋白 1(Rs-AFP1)的 cDNA 全长,在该\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n                              VI\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nWP=9\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n基因的上游连上了一个短小芽孢杆菌 47 株的中壁蛋白(MWP)信号肽,将 Rs-afp1\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n基因的终止密码子突变掉,其后接上绿色荧光蛋白(GFP)基因和 T7 终止子,分\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n别构建成AFP-GFP融合蛋白表达载体pUC118-F1SP' 和pHY300-F1SP' 。\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n                Agfp        Agfp\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nWestern 杂交证实融合蛋白在大肠杆菌 DH5α 中得到了表达。\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n  [附录部分]\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n  杂交墨西哥落羽杉是我国已故著名林木育种家叶培忠教授于 1963 年通过墨\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n西哥落羽杉(母本)与柳杉(父本)杂交所获得的新种。目前,其主要分布在上海、\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n江苏等地。杂交墨杉苗期长势不突出,早年并未引起林木工作者的注意,故目前\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n这些杂交墨西哥落羽杉的分布情况已很难从原始档案中查找到完整的资料。为\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n此,采用随机引物扩增多态性 DNA(RAPD)技术,对 8 个可能是杂交墨西哥落羽\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n杉片林样本、其杂交母本?墨西哥落羽杉和杂交父本的同类?柳杉,共计 12 个\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n样本进行了亲缘关系鉴定和遗传多样性分析。从 31 个随机引物中筛选出 17 个引\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n物,共扩增出 164 条带。其中,多态带有 162 条,占全部条带的 98.8 %。检测结\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n果表明:在 8 号、11 号、12 号 3 个柳杉样本中,11 号样本与原杂交父本的亲缘\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n关系最近;1 号、4 号和 9 号三个片林样本是杂交墨杉群落的可能性最大;5 号\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n片林样本可能是未杂交的墨杉纯林;其他群落的样本是否为杂交墨杉尚不能通过\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n该实验得出明确结论。")
# ('标准文献半衰期算法及实证研究', '陈云鹏;张宝林', '《情报杂志》', '中国标准化研究院;', '2012', '标准文献;半衰期;算法;实证研究;CSSN;国家标准', '针对标准文献不同于图书、期刊等其他科技文献的特点,提出了标准文献半衰期的算法公式,并通过中国标准服务网(CSSN)收录的食品、电子、电气、冶金和农业5个领域的现行国家标准文献进行了实证分析。实证结果表明,不同领域的标准文献半衰期差异明显。')
# ('饿了么:校园走出的“O2O”闭环订餐平台', '陈云鹏', '《上海信息化》', ' ', '2014', '财富传奇;平台模式;OO;线下;用户体验;竞价排名;巨额融资;消费数据;评论人士;支付宝;', '互联网总会孕育出令人大跌眼镜的财富传奇。2014年初夏,大众点评网以8000万美元巨资战略入股网络订餐平台"饿了么"。交易完成后,以"饿了么"创始人团队为首的管理层将继续拥有对公司的控制权、保持独立运营发展,并谋求3年后上市。作为一家名不见经传的网站,"饿了吗"缘何获得网络餐饮大佬的青睐?')
# ('我国分析仪器性能测试标准体系框架研究', '张宝林;赵羽;计雄飞;陈云鹏;汪正范', '《分析测试学报》', '中国标准化研究院;中国分析测试协会;国家有色金属及电子材料分析测试中心;', '2012', '分析仪器;性能测试;标准体系', '该文对我国分析仪器性能测试标准化现状和存在的不足进行了分析,根据当前分析仪器性能测试的工作需求提出了符合我国国情的标准体系框架,并在此基础上给出了对我国分析仪器性能测试标准体系建设的建议。')
# ('绿色荧光蛋白(GFP)基因在短小芽孢杆菌中的组成型表达', '陈云鹏;曲志才;严健;王敬文;叶鸣明;沈大棱', '《复旦学报(自然科学版)》', '复旦大学生命科学学院遗传学研究所基因多样性与设计农业研究中心', '2003', '绿色荧光蛋白;短小芽孢杆菌;启动子活性片段;组成型表达', '采用PCR技术,亚克隆来自短小芽孢杆菌总基因组中的启动子活性片段F1,构建了一个大肠杆菌 短小芽孢杆菌穿梭表达载体pHY300 F1gfp,以缺失启动子的绿色荧光蛋白(GFP)基因为报告基因,检测了该片段在短小芽孢杆菌DX01菌株中的启动活性,在荧光显微镜下,观察到了明亮的绿色荧光,证实活性片段F1具有组成型启动子的功能,GFP基因在短小芽孢杆菌中实现了组成型表达.')
# ('IFLA标准化工作的特点及对我国发展团体标准的启示', '陈云鹏;吕安然;刘亚中;王霞', '《标准科学》', '中国标准化研究院;中国品牌促进会;', '2016', 'IFLA;标准化;团体标准', '本文通过对IFLA标准化工作体系的分析,认为IFLA标准的特点、标准制修订流程、标准版权政策、标准的翻译政策等内容均可作为我国发展团体标准的有益借鉴。')
# ('试论如何提高大学乒乓球教学质量', '曾伟;陈云鹏', '《当代体育科技》', '湖北工业大学体育部;', '2013', '大学体育;乒乓球;教学策略', '作为我国的国球,乒乓球深受大家的喜爱,其训练机制也最为完善。我国很多高校也相继开设了乒乓球选项课,重视对大学生的乒乓球教育,不仅会影响到他们对乒乓球的兴趣,也影响着这项体育事业的继承及大学生终生体育运动观的树立。因此,本文从当前乒乓球教学的现状出发,分析教学方式上的不足,结合高校教育实际,完善教学策略,进一步提高乒乓球教学实效,为社会培养德、智、体全面发展的优秀人才。')
# ('利用RAPD检测技术推测杂交落羽杉群落间的亲缘关系', '陈云鹏;潘士华;张建军;竺唯杰;纽慧娟;曲志才;王敬文;沈大棱;叶增基', '《复旦学报(自然科学版)》', '复旦大学生命科学学院遗传学研究所', '2002', '杂交墨西哥落羽杉;RAPD;聚类分析', '采用随机引物扩增多态性DNA(RAPD)技术,对8个可能是杂交墨西哥落羽杉片林样本、其杂交母本———墨西哥落羽杉和杂交父本的同类———柳杉,共计12个样本进行了亲缘关系鉴定和遗传多样性分析.从31个引物筛选出17个随机引物,共扩增出164条带.其中,多态带有162条,占全部条带的98.8%.检测结果表明:在编号为8,11,12的3个柳杉样本中,11号与原杂交父本亲缘关系最近;1,4,9号是杂交墨杉群落的可能性最大;5号可能是未杂交的墨杉纯林;其他群落的样本是否为杂交墨杉尚不能通过本试验得出明确结论.')
# ('体育教学质量内涵及有效促进策略研究', '陈云鹏', '《内蒙古师范大学学报(教育科学版)》', '湖北工业大学体育部;', '2015', '体育教学质量;内涵;策略', '体育教学效果的好坏最终体现了体育教学质量,而教学质量则主要是由印证每个学生学习效果的各个指标要素聚集而成的,体育的教学质量指向的是教学结果,而不是过程。基于此,本文先从体育教学质量的内涵入手,通过深入剖析影响体育教学质量的因素,从而探究有效促进体育教学质量的策略。')
# ('标准计量分析方法研究及农业应用', '陈云鹏', '《中国农业科学院》', ' ', '2016', '标准文献;文献计量;分析方法;引用;采用;使用', '“标准计量分析方法研究及农业应用”属于文献计量学与标准化学科的交叉研究领域。本课题研究来源于中央基本科研业务费项目“基于引用的标准计量分析方法研究”(项目号:252013Y-3059)。文献计量学经过近百年的发展,基本形成了以引文分析法、时间维度分析法和空间维度分析法为基本框架的研究方法体系,是图书情报学领域方法体系的重要组成部分。文献计量学方法广泛应用于期刊论文、专利文献、网络信息、科学数据等方面,尚未涉足标准文献领域。标准文献作为体现标准化科学与技术进步的最佳实践成果,具有重要的科技情报价值,将文献计量学方法与标准文献有机结合,构建标准计量分析方法有利于标准计量分析方法研究向定量化和科学化的方向发展。因此,本文选题旨在构建适用于标准文献的计量分析方法,既有利于文献计量学方法应用领域的扩展,也有利于标准计量分析方法的完善。本文从标准计量分析的需求入手,结合文献计量学方法,分析标准文献特点,构建了基于采用关系的五维度标准采用影响力评价方法、基于被使用的标准文献半衰期算法、基于被使用的标准文献水平评价方法。(1)构建了五要素模型的标准文献采用影响力评价方法,以标准的采用关系入手,从采用强度、采用效度、采用粘度、采用广度和采用转化速度五个维度,构建了标准才行采用影响力评价指标体系。五要素模型作为定量测定标准文献采用影响力的方法,具有评价指标全面、可量化的优点,通过ISO标准对我国推荐性国家标准采用影响力的实证分析看,该方法可操作性强,能够较全面、客观的反映出标准采用影响力的相关要素。可以将五要素模型作为定量测度标准采用影响力的方法。(2)基于标准文献具有不同于其他科技文献的特点,无法直接使用引用标准来体现标准被使用的情况。本文研究发现企业自我声明使用的标准数据可以较准确的反映标准被企业使用的情况并基于企业自我声明使用的标准数据,结合标准文献特点,构建了适用于标准文献的半衰期新算法,使用此方法对我国国家标准进行了半衰期的实证分析,发现了我国国家标准的老化特点。(3)通过比对分析标准引用与论文引用和专利引用的异同点,发现标准引用无法作为评价标准水平的指标。并基于标准文献具有不同于其他科技文献的特点,无法直接使用引用标准来体现标准被使用的情况。本文构建了基于企业自我声明使用数据的标准水平评价指标。(4)通过将标准文献半衰期计算方法和标准采用影响力方法在农业标准进行的实证分析,证明标准计量分析方法可以较好运用到农业标准数据的分析当中。')
# ('我国MPA教育的现状及思考', '陈云鹏', '《教育理论与实践》', '山西经贸职业学院;', '2009', 'MPA教育;现状;思考', 'MPA是一种注重应用与实践的专业学位研究生教育。近年来我国MPA教育取得了很大的发展,但在人才培养定位、办学模式、课程设置等方面与国外先进的MPA教育相比仍然存在一定的差距。在借鉴西方MPA教育先进办学经验的基础上积极采取措施,可以全面推进我国MPA教育的发展,即政府要加大对MPA教育的投入,大力开展MPA师资队伍建设,尝试建立双导师制;在课程设置上,要坚持应用性,兼顾理论性,强调实践能力的培养;在形式上要灵活多样,以创新我国的MPA教学模式。')
# ('IFLA标准化工作的特点及对我国发展团体标准的启示', '陈云鹏;吕安然;刘亚中;王霞', '《团体标准研究与实践论文集》', '中国标准化研究院', '2016', 'IFLA;标准化;团体标准', '本文通过对IFLA标准化工作体系的分析,认为IFLA标准的特点、标准制修订流程、标准版权政策、标准的翻译政策等内容均可作为我国发展团体标准的有益借鉴。')
# ('1Cr15Ni4Mo3N钢典型热处理故障分析及工艺优化', '程宗辉;曹强;陈云鹏', '《长沙航空职业技术学院学报》', '国营芜湖机械厂;', '2015', 'CrNiMoN;时效;真空淬火', '通过对1Cr15Ni4Mo3N材料典型热处理故障的研究,经断口微观形态分析,分析了该材料典型零件强度、硬度及其组织不合格现象的原因,确定了1Cr15Ni4Mo3N材料硬度随时效温度的变化趋势及与普通不锈钢零件时效硬化制度的不同,优化了1Cr15Ni4Mo3N材料的热处理时效工艺方法。')
# ('对农田水利设施建设的思考', '陈云鹏;陈艳珍', '《理论探索》', '山西经济管理干部学院;中共山西省委党校;', '2011', '农田水利设施;现代农业;资金投入体制', '近年来,频繁发生的水旱灾害,对我国农田水利设施建设提出了挑战。目前我国农田水利设施建设存在的问题主要有:农田水利设施老化失修、设备报废且效益下降严重;以农民投工投劳、筹资为主的农田水利发展机制滞后;农田水利设施建设投入不足,主体责任不清,管理体制不顺。加强农田水利设施建设,应完善多主体、多渠道、多元化的农田水利设施建设资金投入体制,让农民享有农田水利设施建设的选择权和决策权,创新农田水利设施建设的理念和方式方法。')
# ('激光技术在运动损伤和恢复训练中的运用', '陈云鹏', '《激光杂志》', '湖北工业大学;', '2017', '激光技术;运动损伤;恢复训练', '研究激光技术在运动损伤治疗和恢复性训练中的应用,通过激光对运动骨骼肌肉的反馈调节功能,提高运动损伤的恢复效果。通过SPSS12.0对实验数据进行独立样本T检验,准确评估激光功能反馈调节技术同心肌运动激酶机能调控间的关系,分析激光照射锻炼后的甲状腺激素的增长指数,激光技术重组酶活性的基质,分泌抗氧化物酶NHase-TH-SBM,采用激光治疗方法主要有激光骨骼按摩方法和紫外激光照射神经恢复方法,采用统计检验方法分析激光技术对运动损伤相关性。使用Polar Precision Performance 5.0专用分析软件,记录激光照射下的肌肉单收缩曲线,得出TSH抗体激素的差异性特征为P0.04和P0.05,在长期检测的情况下,了解和掌握了激光调控技术对不同性别不同群体身体机能改进程度,指导恢复性训练和运动损伤康复。激光技术应用于运动损伤治疗,能减少神经坏死率,促进骨骼生长,提高骨骼的新生率,结合有效的恢复性训练,对运动损伤的康复具有积极意义。')
# ('基于支撑标准生命周期的标准情报报告服务模式研究', '陈云鹏;王霞;高燕;刘亚中', '《标准科学》', '中国标准化研究院;', '2015', '标准生命周期;情报;服务模式', '标准生命周期是指标准孕育、成长、成熟、老化的过程。本文分析了标准生命周期中各个关键环节的标准情报分析报告服务及建立支撑标准生命周期的标准情报报告技术平台的模式。')
# ('拓展课成为地方多科性大学体育必修课的可行性研究', '陈云鹏;曾伟', '《湖北体育科技》', '湖北工业大学体育部;', '2013', '户外拓展;高校;体育课程改革', '通过问卷调查、逻辑分析法对将"野外生存训练"课程定为高校必修课程进行可行性研究,为普通高校体育课程改革提供参考。')
# ('高校领导班子贯彻执行民主集中制的思考', '孟原生;陈云鹏', '《山西经济管理干部学院学报》', '山西经济管理干部学院', '2005', '民主集中制;“三个代表”重要思想和科学发展观;工作机制;决策机制', '高校贯彻执行民主集中制必须在“三个代表”重要思想和科学发展观的正确指导下,不断完善领导班子工作机制,建立健全民主科学的决策机制,与时俱进,赋之于新的时代特征。其实际成效要通过实践来检验。只有这样,才能不断增强高校领导班子的创造力、凝聚力和战斗力。')
# ('浅析影像传播对体育发展的重要作用——评《体育影像传播——百年中国体育电影研究》', '陈云鹏', '《新闻战线》', '湖北工业大学体育部;', '2016', '电影研究;社会发展体系;电影风格;谢晋导演;暴力美学;一本;电影故事;阶段性发展;家国;政治主题;', '正现阶段,体育已经成为社会发展体系中较为重要的一部分,体育发展关系到社会的进步、国家综合国力的提升。我国体育的可持续发展离不开体育影像,体育影像记载了体育赛事、体育发展历程,是人们了解体育的重要载体。《体育影像传播——百年中国体育电影研究》作为一本研究体育电影,记载体育发展的重要书籍,利用独特的表达方式呈现出了体育影像的阶段性发展与进步。')
# ('纳米TiO_2/沸石复合光催化水处理材料制备与性能研究', '陈云鹏;汪在芹', '《水电与新能源》', '长江科学研究院水环境研究所;', '2017', '纳米TiO_;沸石;负载;水处理材料', '纳米TiO_2光催化材料与技术以其高效、可利用太阳光、无二次污染等优点,在水污染治理领域展现出广阔的应用前景。将纳米TiO_2进行负载复合是解决其在水溶液易团聚、难回收等难题和提高实际降解效果的有效途径。本文采用一种简单易行的固相扩散法将纳米TiO_2在沸石矿物上进行负载,制备得到纳米TiO_2/沸石复合光催化水处理材料。通过扫描电镜、X射线衍射仪、荧光光谱仪等手段对材料微观结构和光催化活性进行了表征和测试。研究表明,沸石负载不仅改善了纳米TiO_2颗粒分散均匀性,而且增强其对紫外-可见光的光响应能力,从而有效提高了复合体在水体中的光催化降解活性。材料光催化活性与其负载配比和焙烧温度息息相关。400℃焙烧制备的90%TiO_2/沸石相对于其他温度和配比具有更高的光催化活性。')
# ('我国独轮车运动发展研究', '陈云鹏', '《湖北体育科技》', '湖北工业大学', '2018', '独轮车;青少年;特征;现状;发展', '现代独轮车集益智、健身、竞技、休闲、极限挑战于一体。采用文献资料法、比较分析法等梳理独轮车运动发展进程,探讨独轮车运动特征。提出我国独轮车运动发展的路径:(1)扎实推进独轮车项目入课堂,促校园独轮车运动百花齐放;(2)加强独轮车俱乐部与政府、学校、社区的共同合作,提升俱乐部影响力;(3)塑造品牌赛事,推进多层次、多类别的赛事交流与活动展示;(4)完善独轮车师资队伍建设;(5)引领独轮车运动与艺术、科技、文化融合创新发展。')
# ('互联网企业价值评估研究', '陈云鹏', '《云南财经大学》', ' ', '2018', '互联网企业;企业价值评估;EBO模型', '互联网使用门槛的降低,极大的丰富了人民的生活方式,随着互联网应用的不停发展,互联网企业依托互联网这个肥沃的资源不断发展壮大,各种形式的互联网企业层出不穷。随着互联网企业的发展壮大,资本市场中常见的企业收购、投资和融资也在互联网行业中日渐增多。但受制于互联网企业自身的一些特点,传统的评估方式在运用到互联网企业评估时会受到很多约束,且难以准确评估出被评估目标的价值。因此,互联网企业价值研究问题逐渐进入人们的眼中。为了更好的解决这个问题,本文在传统EBO模型的基础上加以探究,进一步探索了剩余收益估价法在互联网企业价值评估中的适用性。本文经过对原有评估方法在互联网企业价值评估中的思考,发现受制于互联网行业自身的特质,难以对互联网企业进行精准的评价。但是互联网企业的价值又是当前社会人们急需解决的问题。经过研究发现,EBO模型在运用到互联网企业价值估算时拥有着其他方法所不具备的优越性。随后经过探索找到了一条适合互联网行业价值估算的评估程序和相关理论依据。再将新华网有限公司带入到上述研究的互联网企业价值评估程序中进行估算后发现,相较于传统的企业价值估价方法,EBO模型的评估结果与新华网企业评估时点的市场价值更加接近,也就是说当采用EBO模型对互联网企业的相关价值进行估算,获得的结果更容易让投资者满意,更有利于互联网投资者做出有利的决策。')
# ('学科期刊平均影响因子的新算法', '陈云鹏;高柳滨', '《图书情报工作》', '中国科学院国家科学图书馆;中国科学院上海生命科学信息中心;', '2009', '学科期刊平均影响因子;AIF;GIF;学科期刊影响因子序列中位数', '通过检索ISIJCR数据库收录的2005、2006和2007年包括生物、地理、历史、机械等学科在内10个学科的数据及分析各个学科的期刊影响因子序列,发现各学科的期刊影响因子序列分布极不均衡、数据分布呈现明显的单极化以及传统的两种学科期刊平均影响因子的计算算法存在结果"虚高"的现象,提出一种科学反映学科期刊整体水平的新算法——学科期刊影响因子中位数。')
# ('UCMW轧机带钢边缘降的成因分析与控制', '陈云鹏', '《轧钢》', '宝山钢铁股份有限公司宝钢分公司;', '2010', 'UCMW轧机;边缘降;K-WRS工作辊;控制性能', '带钢边部厚度减薄量是冷轧成品带钢一个重要质量指标。本文以宝钢1550mm UCMW冷连轧机为研究对象,通过数值仿真,分析了冷轧带钢边部减薄的主要影响因素,研究了1550mmUCMW冷连轧机配置的K-WRS工作辊的边缘降控制性能,同时对其边缘降控制系统进行了消化分析,对比了边缘降控制系统投入前后的控制效果,以进一步指导实际生产。')
# ('基于引证系数的论文影响力评价方法研究', '钟文一;陈云鹏', '《情报科学》', '贵州师范大学图书馆;中国标准化研究院;', '2011', '引证系数;论文影响力;期刊影响力;实证研究', '基于论文评价与期刊评价的联系和区别提出了论文引证系数的概念,并利用引证系数概念考证某一具体论文被引证的情况,兼顾论文所在期刊的影响力水平,同时消除频繁自引引起的论文影响力量化值放大化的问题,对论文总被引次数和影响因子两个指标进行了优化处理,建立论文引证系数的数学模型,并通过实证数据验证了引证系数模型的可行性和合理性。')
# ('技术标准情报分析服务研究', '陈云鹏;周国民', '《兰台世界》', '中国农业科学院;中国标准化研究院;', '2016', '技术标准;标准生命周期;情报服务模式', '本文将生命周期的概念引入标准情报服务理论与方法当中,对技术标准生命周期中的孕育、成长、成熟和老化的四个阶段与标准制修订的关键环节进行了映射,并分析了标准生命周期中各个关键环节的标准情报分析的服务需求,基于需求建立了支撑标准生命周期的标准情报技术平台,提出了技术标准情报分析服务的模式。')
# ('标准引用与论文引用的比较研究', '陈云鹏;周国民;谢晨;汪滨', '《科研管理》', '中国农业科学研究院;中国标准化研究院;', '2017', '标准引用;论文引用;比较研究', '标准和论文是科技成果的重要文献载体,具有重要的情报价值。本文通过文献调研法,从引用范围、引用目的、引用动机、关联性等维度比较了标准引用与论文引用的异同点。结论是标准引用与论文引用在表现出相似的知识关联关系和关联性,两者在引用条件、引用范围、引用目的、出版物性质、引用主体、引用内容选择等方面存在差异。')
# ('芸薹类蔬菜基因组DNA遗传多样性的RAPD分析', '陈云鹏;曹家树;缪颖;叶纨芝', '《浙江大学学报(农业与生命科学版)》', '浙江大学园艺系!浙江杭州310029', '2000', '芸薹类;遗传多样性;RAPD', '采用随机引物扩增多态性 DNA( RAPD)技术 ,对芸薹类 ( 2 n=2 0 )蔬菜作物的 3 3个品种进行了遗传多样性检测 .从 70个引物中筛选出 3 7个引物 ,共扩增出 3 53带 .其中 ,多态带有 2 60条 ,扩增片段长度大多数集中在 0 .9～ 1 .6kb之间 .不同引物的检测效率相差很大 .运用 5个引物扩增的 1 0条RAPD特征带 ,可以作为一组 DNA指纹 ,区分所有供试 7个大白菜品种')
# ('标准引用与论文引用、专利引用的异同比较研究', '陈云鹏;张明;高燕;王霞', '《标准科学》', '中国标准化研究院;', '2015', '标准引用;专利引用;论文引用', '标准、专利和论文是科技成果的重要文献载体,三者在引用方面的特点并不相同。本文通过实证分析法和文献调研法,从引用分布、引用动机、知识关联三个维度比较了标准引用与专利引用、论文引用的异同点。结论是标准引用与专利引用、论文引用在文献老化、领域分布、语种分布方面相似性较大,其在引用动机、出版物性质、引文主体等方面与专利引用、论文引用有一定差异。此外,标准引用呈现出较好的知识关联性,并存在潜在的知识产权问题。')
# ('高校高水平运动队存在的价值研究', '陈云鹏', '《湖北体育科技》', '湖北工业大学体育部;', '2011', '高校;高水平运动队;存在;价值', '我国高校高水平运动队建设仍处在探索阶段,08年奥运会上大学生运动员取得的成绩给我们提出了新的课题,高校高水平运动队的建设到底该如何进行下去,通过对高校高水平运动队存在的价值深入研究,为我国高校高水平运动队建设提供参考。')
# ('国内外动力用锂离子电池主要标准对比分析', '计雄飞;陈云鹏;魏利伟;赵亚娟', '《标准科学》', '中国标准化研究院;中国科学院国家科学图书馆;', '2014', '电动汽车;锂离子电池;标准对比', '锂离子电池近年来作为主要动力源,被大量应用于电动汽车。本文分析了国际(ISO/IEC)、欧盟(EN)、美国、日本及国内的主要动力用锂离子电池标准,对各国锂离子电池标准涉及领域、发布时间和数量进行了分析,并针对标准中涉及的具体技术要求(技术指标)进行了差异性对比分析。')
# ('多媒体演示系统的开发与研制——以普通高校乒乓球专选课教学为例', '曾伟;陈云鹏', '《湖北体育科技》', '湖北工业大学体育部;', '2014', '乒乓球;技术课教学;多媒体课件;开发与研制', '利用计算机多媒体课件进行体育教学已成为高校体育教师的必备教学手段之一。这不仅能极大地调动学生学习的积极性和主动性,也促进了教学质量的提高。结合乒乓球项目的特点和教学实际,详细阐述了乒乓球技术课教学多媒体系统的开发与研制过程,为加快多媒体教学手段在高校体育技术课中的应用提供参考。')
# ('镀液中锡泥对镀锡板表面特性的影响', '陈云鹏;周庚瑞;黄久贵;李建中', '《电镀与涂饰》', '宝钢新日铁汽车板有限公司;宝山钢铁股份有限公司冷轧薄板厂;东北大学材料与冶金学院;', '2014', '镀锡板;锡泥;表面状态;性能', '通过扫描电镜、电化学极化曲线测量和划痕试验,研究了镀液中锡泥质量浓度对镀锡板表面状态、耐蚀性、结合力等性能的影响。结果表明,镀液中的锡泥含量对镀锡板的性能有很大影响。随镀液中锡泥质量浓度的增大,镀锡板表面逐渐出现白点并增大,锡层晶粒也逐渐变大。与从高浓度锡泥镀液中制备的镀锡板相比,从低浓度锡泥镀液中制备的镀锡板耐蚀性和结合力都较好。实际生产中应控制镀液中锡泥的质量浓度小于10 g/L。')
# ('标准分析及其在情报研究中的应用', '陈云鹏;卢丽丽;王颖', '《标准科学》', '中国标准化研究院;北京华盛中天咨询有限公司;', '2014', '标准分析;情报研究;标准引用', '文章在介绍标准文献的基础上,结合标准化原理,探讨标准分析方法,即标准分析可以分为定性分析和定量分析。定量分析是对标准相关指标的计算与统计;定性分析是对标准信息的一种技术分析,具有很强的专业性。并且从情报研究的实践出发,以燃气具领域为例,从标准体系布局、标准引用、标准半衰期等角度进行分析。')
# ('城中村社会保障机制构建的路径选择——基于制度关联视角的分析', '陈云鹏;陈艳珍;李亮亮', '《中国行政管理》', '山西经贸职业学院;中共山西省委党校;山西大学政治与公共管理学院;', '2011', '制度关联;城中村;社会保障;城乡统筹', '城乡统筹背景下的城中村社会保障是城市化进程中值得关注的问题,制度间的失衡与悖论是城中村社会保障机制的构建和社会关系的有序与和谐的制度性障碍。本文通过制度关联这一理论工具,在总结目前城中村社会保障机制类型的基础上,认为整体联动的、渐进式的、强致性和诱致性相结合的路径符合我国建立城中村社会保障的实际,为失地农民社会保障提供政策向导。')
# ('GB/T1.1的技术标准演进研究', '陈云鹏;汪滨;吕安然', '《标准科学》', '中国标准化研究院;中国品牌建设促进会;', '2015', '技术标准;标准演进;GB/T;.', 'GB/T 1.1-2009的历史版本包括GB 1-58、GB 1.1-81、GB 1.1-87、GB/T 1.1-93、GB/T 1.1-2000等5个版本,本文针对GB/T 1.1开展技术标准演进研究,对比分析了6个不同历史时期的GB/T 1.1的技术内容,分析结论认为我国应重视已废止标准在我国标准研究与应用工作中的作用并加强我国标准宣贯材料的长期保存工作。')
# ('标准信息集成研究', '卢丽丽;陈云鹏;张宝林;计雄飞', '《标准科学》', '中国标准化研究院;', '2012', '标准;信息;集成', '文章介绍了标准信息集成的特点及优势,分析了国内外标准信息服务的发展现状。针对当前标准信息服务存在的问题,提出了标准知识集成的建议。')
# ('“SoLoMo+O2O”会带来什么?', '陈云鹏', '《上海信息化》', ' ', '2012', '消费者;互联网产业;商业模式;移动互联网;在线支付;电子商务;用户需求;概念;信息化;创意', '由Social(社交)、Local(本地化)和Mobile(移动)三个关键词整合而成的"SoLoMo"概念正日益风靡全球互联网产业,而"O2O"(Online to Offline)模式则被誉为"SoLoMo"概念最好的体现方式。当"SoLoMo"遇上"O2O",这对创新组合会催生哪些有创意的商业模式?')
# ('浅析事业单位绩效工资改革', '陈艳珍;陈云鹏', '《山西经济管理干部学院学报》', '中共山西省委党校;山西经贸职业学院;', '2010', '事业单位;绩效工资;改革', '事业单位承担着社会最基本的公共服务。目前事业单位正在全面推行绩效工资改革,如何处理好改革的力度与群众的可承受程度的关系,事关4 000万事业单位从业人员的切身利益和改革的成败。只有正确地坚持改革的原则、明晰改革的思路、把握改革的要求,积极稳妥地处理好各种关系,才能推进改革,实现增进社会公益与绩效导向的双赢。')
# ('基于AHP方法的国内外开放存取系统评价研究', '陈云鹏', '《现代情报》', '中国科学院国家科学图书馆;', '2009', '开放存取系统;服务质量;评价;AHP', '文章针对开放存取系统服务质量评价的复杂性、模糊性特点,采用AHP分析法,构建其评价模型,对国内开放存取系统的服务质量的综合性评价进行研究。')
# ('冷轧带钢力学性能在线检测技术进展', '陈云鹏;李茫茫;唐成龙', '《理化检验(物理分册)》', '宝钢新日铁汽车板有限公司;宝山钢铁股份有限公司研究院;', '2017', '冷轧带钢;力学性能;在线检测', '力学性能是衡量带钢产品质量的一个重要指标,是下游产品设计和选材的主要依据,检测带钢的力学性能参数是确保其产品质量的一种重要手段。综述了各种在线检测技术,包括巴克豪森噪声法、多频涡流法、电磁感应法、多磁参数综合法等,重点分析了各种技术的工作原理及其研究进展,探讨了各种技术方法在实际中的应用情况,并指出了它们各自的适用范围和优缺点。最后以宝钢高强薄带钢力学性能在线检测装置3MA系统为例,分析了其检测精度和效果。结果表明:该3MA系统的检测误差在规定范围内;相对于传统的离线检测技术,在线检测技术可保持冷轧带钢的完整性、连续实时检测,能够根据检测数据实时调整生产工艺,保证冷轧带钢的产品质量。')
